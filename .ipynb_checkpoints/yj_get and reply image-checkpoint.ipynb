# %%
'''

用戶傳照片消息給Line

我方使用 消息的id 向Line 索取照片

'''
# Out:
# '\n\n用戶傳照片消息給Line\n\n我方使用 消息的id 向Line 索取照片\n\n'

# %%
"""

啟用伺服器基本樣板

"""
# 引用Web Server套件
from flask import Flask, request, abort

# 從linebot 套件包裡引用 LineBotApi 與 WebhookHandler 類別
from linebot import (
    LineBotApi, WebhookHandler
)

# 引用無效簽章錯誤
from linebot.exceptions import (
    InvalidSignatureError
)

# 載入設定檔

import json
secretFileContentJson=json.load(open("./line_secret_key",'r'))
server_url=secretFileContentJson.get("server_url")


# 設定Server啟用細節
app = Flask(__name__,static_url_path = "/images" , static_folder = "./images/" )

# 生成實體物件
line_bot_api = LineBotApi(secretFileContentJson.get("channel_access_token"))
handler = WebhookHandler(secretFileContentJson.get("secret_key"))

# 啟動server對外接口，使Line能丟消息進來
@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        abort(400)

    return 'OK'

# %%
from linebot.models import * 
import os

# %%
#文字圖片消息list

img_url='https://%s/images/'% server_url

introtext=[TextSendMessage(text='圖像風格遷移指的是將圖像A的風格轉換到圖像B中去，得到新的圖像Style Transfer')]

NTSintro_list=[
               TextSendMessage(text='它的原理是由德國圖賓根大學Leon A. Gatys等人在A Neural Algorithm of Artistic Style論文中所提出，利用這個公式將內容損失函數降到最小，讓我們原本照片的內容盡可能地保留下來'),
               ImageSendMessage(
        original_content_url=img_url+'intro/nts_intro1.png',
        preview_image_url=img_url+'intro/nts_intro1.png' 
    ),
              TextSendMessage(text='再利用這個公式中的格拉姆(Gram)矩陣取得紋理色調，將風格損失函數降到最小，讓我們盡可能地將紋理保留'),
              ImageSendMessage(
        original_content_url=img_url+'intro/nts_intro2.png',
        preview_image_url=img_url+'intro/nts_intro2.png' 
    ),
              TextSendMessage(text='利用Pretrained models: imagine-vgg-verydeep-19 下去做訓練，出自於\'Very Deep Convolutional Networks for Large-Scale Image Recognition\', Karen Simonyan and Andrew Zisserman, arXiv technical report, 2014\t 輸入NST，回到上一層，輸入GO，回主選單')
]

FNSintro_list=[TextSendMessage(text='根据Neural Style的速度慢的问题改善而成，簡單地來說是先使用風格圖預訓練出風格模型，再加入內容圖來進行風格轉換。'),
               ImageSendMessage(
        original_content_url=img_url+'intro/fns_intro1.png',
        preview_image_url=img_url+'intro/fns_intro1.png'
    ),
               TextSendMessage(text='整個網絡是由圖像轉換網絡TT（image transfrom net）和預訓練好的損失計算網絡VGG-16(loss network)組成。\
               Image Transformation network是一個deep residual conv netwrok，用來將輸入圖像（content image）直接transform為帶有style的圖像，網絡參數可更新。\
               loss network 網絡結構與之前的Neural style transfer，這裡主要是計算content loss和style loss， 注意不像neural style裡面會對圖像做像素級更新。'),
               TextSendMessage(text='輸入FNS，回到上一層，輸入GO，回主選單')
              
              ]
iteration_1_350=[TextSendMessage(text='Iteration 為350時'),ImageSendMessage(
        original_content_url=img_url+'intro/2op350.jpg',
        preview_image_url=img_url+'intro/2op350.jpg' 
    )]
iteration_1_500=[TextSendMessage(text='Iteration 為500時'),ImageSendMessage(
        original_content_url=img_url+'intro/2op500.jpg',
        preview_image_url=img_url+'intro/2op500.jpg' 
    )]
iteration_1_1000=[TextSendMessage(text='Iteration 為1000時'),ImageSendMessage(
        original_content_url=img_url+'intro/2op1000.jpg',
        preview_image_url=img_url+'intro/2op1000.jpg' 
    )]
iteration_1_1500=[TextSendMessage(text='Iteration 為1500時'),ImageSendMessage(
        original_content_url=img_url+'intro/2op1500.jpg',
        preview_image_url=img_url+'intro/2op1500.jpg' 
    )]
iteration_1_2000=[TextSendMessage(text='Iteration 為2000時'),ImageSendMessage(
        original_content_url=img_url+'intro/2op2000.jpg',
        preview_image_url=img_url+'intro/2op2000.jpg' 
    )]
iteration_1_3500=[TextSendMessage(text='Iteration 為3500時'),ImageSendMessage(
        original_content_url=img_url+'intro/2op3500.jpg',
        preview_image_url=img_url+'intro/2op3500.jpg' 
    )]

iteration_2_500=[TextSendMessage(text='Iteration 為500時'),ImageSendMessage(
        original_content_url=img_url+'intro/1op500.jpg',
        preview_image_url=img_url+'intro/1op500.jpg' 
    )]
iteration_2_1000=[TextSendMessage(text='Iteration 為1000時'),ImageSendMessage(
        original_content_url=img_url+'intro/1op1000.jpg',
        preview_image_url=img_url+'intro/1op1000.jpg' 
    )]
iteration_2_1500=[TextSendMessage(text='Iteration 為1500時'),ImageSendMessage(
        original_content_url=img_url+'intro/1op1500.jpg',
        preview_image_url=img_url+'intro/1op1500.jpg' 
    )]
iteration_2_2000=[TextSendMessage(text='Iteration 為2000時'),ImageSendMessage(
        original_content_url=img_url+'intro/1op2000.jpg',
        preview_image_url=img_url+'intro/1op2000.jpg' 
    )]

# %%
#imagemap

iterationmap = ImagemapSendMessage(
    base_url='https://%s/images/iterationmap.png#'%server_url,
    alt_text='看看不同iteration的效果',
    base_size=BaseSize(height=2080, width=1040),
    actions=[
         MessageImagemapAction(
            text="[::iteration_style:] candy",
            area=ImagemapArea(x=246,y=1042, width=546,height=539 )
                                ),
                 MessageImagemapAction(
            text="[::iteration_style:] mosaic",
            area=ImagemapArea(x=251,y=1596, width=536,height=443 )
                                )
        
    ]


)


stylemap = ImagemapSendMessage(
    base_url='https://%s/images/stylemap.png#'%server_url,
    alt_text='風格照片地圖',
    base_size=BaseSize(height=1533, width=1040),
    actions=[

        MessageImagemapAction(
            text="[::style:] la_muse",
            area=ImagemapArea(x=16,y=28, width=508,height=508 )
                                ),
        MessageImagemapAction(
            text="[::style:] rain_princesse",
            area=ImagemapArea(x=541,y=30, width=481,height=479 )
                                ),
        MessageImagemapAction(
            text="[::style:] udnie",
            area=ImagemapArea(x=16,y=581, width=515,height=514 )
                                ),
        MessageImagemapAction(
            text="[::style:] the_scream",
            area=ImagemapArea(x=608,y=566, width=400,height=513 )
                                ),
        MessageImagemapAction(
            text="[::style:] the_shipwreck_of_the_minotaur",
            area=ImagemapArea(x=0,y=1133, width=492,height=358 )
                                ),
        MessageImagemapAction(
            text="[::style:] wave",
            area=ImagemapArea(x=520,y=1137, width=520,height=315 )
                                )
    ]
)    
style_dict={
    "[::style:] la_muse":"la_muse.ckpt",
    "[::style:] rain_princess":"rain_princess.ckpt",
    "[::style:] wave":"wave.ckpt",
    "[::style:] the_shipwreck_of_the_minotaur":"wreck.ckpt",
    "[::style:] the_scream":"scream.ckpt",
    "[::style:] udnie":"udnie.ckpt"
}
style_text_message=TextSendMessage(text="請上傳想轉換風格的圖,請稍後，不要急歐~")

# %%
# button
introbutton = TemplateSendMessage(
        alt_text='開始導讀囉~',
        template=ButtonsTemplate(
            title='歡迎加入玩轉風格轉換-導讀系統機器人',
            text='你知道什麼是風格轉換(style transfer)嗎?',
            thumbnail_image_url='https://%s/images/stata.jpg#'%server_url,
            actions=[
        PostbackTemplateAction(
            label= "風格轉換",
            text="Q.甚麼是風格轉換",
            data="intro1"
        ),
        PostbackTemplateAction(
            label= "NST",
            text="Q.甚麼是Neural style transfer",
            data="intro2"
        ),
        PostbackTemplateAction(
            label= "FNS",
            text="Q.甚麼是Fast Neural style",
            data="intro3"
        )
        ]
        )
    )

NTSbutton = TemplateSendMessage(
        alt_text='Neural style transfer介紹',
        template=ButtonsTemplate(
            title='Neural style transfer',
            text='來了解一下 Neural style transfer 吧!',
            thumbnail_image_url='https://%s/images/stata.jpg#'%server_url,
            actions=[
        PostbackTemplateAction(
            label= "原理簡介",
            text="Neural style transfer原理簡介",
            data="NTS1"
        ),
        PostbackTemplateAction(
            label= "看看iteration的差別",
            text="看看iteration的差別",
            data="NTS2"
        )
        ]
        )
    )

FNSbutton = TemplateSendMessage(
        alt_text='Fast Neural style介紹',
        template=ButtonsTemplate(
            title='Fast Neural style',
            text='來了解一下 Fast Neural style 吧!',
            thumbnail_image_url='https://%s/images/stata.jpg#'%server_url,
            actions=[
        PostbackTemplateAction(
            label= "原理簡介",
            text="Fast Neural style原理簡介",
            data="FNS1"
        ),
        PostbackTemplateAction(
            label= "玩玩看",
            text="玩玩看風格轉換",
            data="FNS2"
        )
        ]
        )
    )

iteration1_button = TemplateSendMessage(
        alt_text='看看不同iteration的效果',
        template=ButtonsTemplate(
            title='看看不同iteration的效果',
            text='來看看不同iteration的效果吧!',
            thumbnail_image_url='https://%s/images/intro/s3.jpg#'%server_url,
            actions=[
        PostbackTemplateAction(
            label= "350",
            text="iteration = 350",
            data="I11"
        ),
        PostbackTemplateAction(
            label= "1000",
            text="iteration = 1000",
            data="I13"
        ),
PostbackTemplateAction(
            label= "2000",
            text="iteration = 2000",
            data="I15"
        ),
                        PostbackTemplateAction(
            label= "3500",
            text="iteration = 3500",
            data="I16"
        )
        ]
        )
    )

iteration2_button = TemplateSendMessage(
        alt_text='看看不同iteration的效果',
        template=ButtonsTemplate(
            title='看看不同iteration的效果',
            text='來看看不同iteration的效果吧!',
            thumbnail_image_url='https://%s/images/intro/s2.jpg#'%server_url,
            actions=[
       
        PostbackTemplateAction(
            label= "500",
            text="iteration = 500",
            data="I21"
        ),
        PostbackTemplateAction(
            label= "1000",
            text="iteration = 1000",
            data="I22"
        ),
        PostbackTemplateAction(
            label= "1500",
            text="iteration = 1500",
            data="I23"
        ),
PostbackTemplateAction(
            label= "2000",
            text="iteration = 2000",
            data="I24"
        )
        ]
        )
    )


iterationmap_dict={
    "[::iteration_style:] candy":iteration1_button,
    "[::iteration_style:] mosaic":iteration2_button
}

# %%
'''

撰寫用戶關注時，我們要處理的商業邏輯

1. 取得用戶個資，並存回伺服器
2. 把先前製作好的自定義菜單，與用戶做綁定
3. 回應用戶，歡迎用的文字消息與圖片消息

'''


# 載入Follow事件
from linebot.models.events import (
    FollowEvent
)

# 載入requests套件
import requests

# 消息清單
reply_message_list = [
                            TextSendMessage(text="歡迎來到導讀機器人"),
                            introbutton]


# 告知handler，如果收到FollowEvent，則做下面的方法處理
@handler.add(FollowEvent)
def reply_text_and_get_user_profile(event):
    
    # 取出消息內User的資料
    user_profile = line_bot_api.get_profile(event.source.user_id)
        
     # 將用戶資訊存在檔案內
    with open("../users.txt", "a") as myfile:
        myfile.write(json.dumps(vars(user_profile),sort_keys=True))
        myfile.write('\r\n')
        
        
    # 將菜單綁定在用戶身上
    linkRichMenuId=secretFileContentJson.get("rich_menu_id")
    linkMenuEndpoint='https://api.line.me/v2/bot/user/%s/richmenu/%s' % (event.source.user_id, linkRichMenuId)
    linkMenuRequestHeader={'Content-Type':'image/jpeg','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}
    lineLinkMenuResponse=requests.post(linkMenuEndpoint,headers=linkMenuRequestHeader)
    
    # 回覆文字消息與圖片消息
    line_bot_api.reply_message(
        event.reply_token,
        reply_message_list
    )

# %%
#用戶點擊button後，觸發postback event，對其回傳做相對應處理

@handler.add(PostbackEvent)
def handle_post_message(event):
    user_profile = line_bot_api.get_profile(event.source.user_id)
    if (event.postback.data.find('intro1')== 0):
        with open("../user_profile_business.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            introtext 
            )
    elif (event.postback.data.find('Intro') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
                introbutton
            
            )
    elif (event.postback.data.find('intro2') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
                NTSbutton
            
            )
    elif (event.postback.data.find('intro3') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
                FNSbutton
            
            )
    elif (event.postback.data.find('NTS1') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            NTSintro_list
            )
    elif (event.postback.data.find('NTS2') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            iterationmap
            )

    elif (event.postback.data.find('FNS1') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            FNSintro_list
            )
    elif (event.postback.data.find('FNS2') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            stylemap
            )
    elif (event.postback.data.find('I11') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            iteration_1_350
            )
    elif (event.postback.data.find('I12') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            iteration_1_500
            )
    elif (event.postback.data.find('I13') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            iteration_1_1000
            )
    elif (event.postback.data.find('I14') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            iteration_1_1500
            )
    elif (event.postback.data.find('I15') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            iteration_1_2000
            )
    elif (event.postback.data.find('I16') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            iteration_1_3500
            )
    elif (event.postback.data.find('I21') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            iteration_2_500
            )
    elif (event.postback.data.find('I22') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            iteration_2_1000
            )
    elif (event.postback.data.find('I23') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            iteration_2_1500
            )
    elif (event.postback.data.find('I24') == 0):
        with open("../user_profile_tutorial.txt", "a") as myfile:
            myfile.write(json.dumps(vars(user_profile),sort_keys=True))
            myfile.write('\r\n')
            line_bot_api.reply_message(
            event.reply_token,
            iteration_2_2000
            )
    else:
        pass

# %%
import os

from linebot.models import *



@handler.add(MessageEvent, message=(ImageMessage, TextMessage))

def handle_message(event):
    
    if isinstance(event.message, TextMessage):
        global prestyle
        if event.message.text == "Go":
            line_bot_api.reply_message(event.reply_token,introbutton)
        elif event.message.text.find('::style:')!= -1:
            prestyle=style_dict.get(event.message.text)
            line_bot_api.reply_message(
            event.reply_token,style_text_message
            )
        
        elif event.message.text.find('::iteration_style:')!= -1:
            iteration_message=iterationmap_dict.get(event.message.text)
            line_bot_api.reply_message(
            event.reply_token,iteration_message
            )
        elif event.message.text == "NST":
            line_bot_api.reply_message(event.reply_token,NTSbutton)
        elif event.message.text == "FNS":
            line_bot_api.reply_message(event.reply_token,FNSbutton)
       # elif event.message.text == "直接玩玩看吧!":
           # line_bot_api.reply_message(event.reply_token,stylemap)
        #elif event.message.text == "了解一下!":
          #  line_bot_api.reply_message(event.reply_token,introbutton)
                        

        else:
            pass

#若收到圖片消息時，

#先回覆用戶文字消息及原圖，並從回傳風格圖。
    elif isinstance(event.message, ImageMessage):        
        message_content = line_bot_api.get_message_content(event.message.id)

        image_local_file = './images/'+ event.message.id +".jpg"

        with open('./images/'+event.message.id+'.jpg', 'wb') as fd:
            for chunk in message_content.iter_content():
                fd.write(chunk)
        img2_url='https://%s/images/'% server_url

        os.system('python evaluate.py --checkpoint ./prestylemodel/'+prestyle+' --in-path '+image_local_file+ ' --out-path ./images/result/')

        line_bot_api.reply_message(
            event.reply_token,
            [TextSendMessage(text='您的圖片已上傳, 請稍待...'),ImageSendMessage(
        original_content_url=img2_url+'result/'+event.message.id+'.jpg',
        preview_image_url=img2_url+'result/'+event.message.id+'.jpg' 
    )])

# %%
'''

啟動Server

'''
if __name__ == "__main__":
    app.run(host='0.0.0.0')
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
